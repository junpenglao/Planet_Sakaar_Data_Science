# %%
import pymc3 as pm
import numpy as np
import theano.tensor as tt

# %%
# Initialize random number generator
np.random.seed(123)

# True parameter values
alpha, sigma = 1, 1
beta = [1, 2.5]

# Size of dataset
size = 100

# Predictor variable
X1 = np.random.randn(size)
X2 = np.random.randn(size) * 0.2

# Simulate outcome variable
data = alpha + beta[0]*X1 + beta[1]*X2 + np.random.randn(size)*sigma

# %%
from pymc3.distributions.dist_math import incomplete_beta, incomplete_beta_cfe, incomplete_beta_ps
def beta_logcdf(a, b, value):
    value = pm.floatX(tt.as_tensor(value))
    return tt.switch(
        tt.le(value, 0),
        -np.inf,
        tt.switch(
            tt.ge(value, 1),
            0,
            tt.log(incomplete_beta(a, b, value))
        )
    )

# %%
with pm.Model() as basic_model:
    # Priors for unknown model parameters
    a = pm.HalfNormal('alpha', sd=2)
    b = pm.HalfNormal('beta', sd=2)
    sigma = pm.HalfNormal('sigma', sd=1)

    m1 = beta_logcdf(a, b, 0.1)
    
    # Likelihood (sampling distribution) of observations
    Y_obs = pm.Normal('Y_obs', mu=m1, sd=sigma, observed=data)

# %%
basic_model.test_point
# Out:
# {'alpha_log__': array(0.46735583),
#  'beta_log__': array(0.46735583),
#  'sigma_log__': array(-0.22579135)}

# %%
basic_model.logp(basic_model.test_point)
# Out:
# array(-1509.42694554)

# %%
with basic_model:
    trace = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-21-0c1e83ce45ba> in <module>()
#       1 with basic_model:
# ----> 2     trace = pm.sample()
#
# ~/Documents/pymc3/pymc3/sampling.py in sample(draws, step, init, n_init, start, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, **kwargs)
#     389                 start_, step = init_nuts(init=init, chains=chains, n_init=n_init,
#     390                                          model=model, random_seed=random_seed,
# --> 391                                          progressbar=progressbar, **kwargs)
#     392                 if start is None:
#     393                     start = start_
#
# ~/Documents/pymc3/pymc3/sampling.py in init_nuts(init, chains, n_init, model, random_seed, progressbar, **kwargs)
#    1472             'Unknown initializer: {}.'.format(init))
#    1473
# -> 1474     step = pm.NUTS(potential=potential, model=model, **kwargs)
#    1475
#    1476     return start, step
#
# ~/Documents/pymc3/pymc3/step_methods/hmc/nuts.py in __init__(self, vars, max_treedepth, early_max_treedepth, **kwargs)
#     150         `pm.sample` to the desired number of tuning steps.
#     151         """
# --> 152         super().__init__(vars, **kwargs)
#     153
#     154         self.max_treedepth = max_treedepth
#
# ~/Documents/pymc3/pymc3/step_methods/hmc/base_hmc.py in __init__(self, vars, scaling, step_scale, is_cov, model, blocked, potential, dtype, Emax, target_accept, gamma, k, t0, adapt_step_size, step_rand, **theano_kwargs)
#      70         vars = inputvars(vars)
#      71
# ---> 72         super().__init__(vars, blocked=blocked, model=model, dtype=dtype, **theano_kwargs)
#      73
#      74         self.adapt_step_size = adapt_step_size
#
# ~/Documents/pymc3/pymc3/step_methods/arraystep.py in __init__(self, vars, model, blocked, dtype, **theano_kwargs)
#     226
#     227         func = model.logp_dlogp_function(
# --> 228             vars, dtype=dtype, **theano_kwargs)
#     229
#     230         # handle edge case discovered in #2948
#
# ~/Documents/pymc3/pymc3/model.py in logp_dlogp_function(self, grad_vars, **kwargs)
#     720         varnames = [var.name for var in grad_vars]
#     721         extra_vars = [var for var in self.free_RVs if var.name not in varnames]
# --> 722         return ValueGradFunction(self.logpt, grad_vars, extra_vars, **kwargs)
#     723
#     724     @property
#
# ~/Documents/pymc3/pymc3/model.py in __init__(self, cost, grad_vars, extra_vars, dtype, casting, **kwargs)
#     453             self._cost, grad_vars, self._ordering.vmap)
#     454
# --> 455         grad = tt.grad(self._cost_joined, self._vars_joined)
#     456         grad.name = '__grad'
#     457
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in grad(cost, wrt, consider_constant, disconnected_inputs, add_names, known_grads, return_disconnected, null_gradients)
#     603
#     604     rval = _populate_grad_dict(var_to_app_to_idx,
# --> 605                                grad_dict, wrt, cost_name)
#     606
#     607     for i in xrange(len(rval)):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in _populate_grad_dict(var_to_app_to_idx, grad_dict, wrt, cost_name)
#    1369         return grad_dict[var]
#    1370
# -> 1371     rval = [access_grad_cache(elem) for elem in wrt]
#    1372
#    1373     return rval
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1369         return grad_dict[var]
#    1370
# -> 1371     rval = [access_grad_cache(elem) for elem in wrt]
#    1372
#    1373     return rval
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in <listcomp>(.0)
#    1019             inputs = node.inputs
#    1020
# -> 1021             output_grads = [access_grad_cache(var) for var in node.outputs]
#    1022
#    1023             # list of bools indicating if each output is connected to the cost
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_grad_cache(var)
#    1324                     for idx in node_to_idx[node]:
#    1325
# -> 1326                         term = access_term_cache(node)[idx]
#    1327
#    1328                         if not isinstance(term, gof.Variable):
#
# ~/anaconda3/lib/python3.6/site-packages/theano/gradient.py in access_term_cache(node)
#    1160
#    1161                 input_grads = node.op.L_op(inputs, node.outputs,
# -> 1162                                            new_output_grads)
#    1163
#    1164                 if input_grads is None:
#
# ~/anaconda3/lib/python3.6/site-packages/theano/scan_module/scan_op.py in L_op(self, inputs, outs, dC_douts)
#    2220             for x in self.outer_sitsot_outs(outs):
#    2221                 if hasattr(x[::-1][:-1].tag, 'test_value'):
# -> 2222                     assert (x[::-1][:-1].tag.test_value.shape[0] == n)
#    2223             for x in self.outer_nitsot_outs(outs):
#    2224                 if hasattr(x[::-1].tag, 'test_value'):
#
# AssertionError:
